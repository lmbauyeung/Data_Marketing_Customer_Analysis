# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import QuantileTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from scipy.stats import boxcox
pd.options.display.max_rows = 50
pd.options.display.max_columns = 999
import warnings
warnings.filterwarnings('ignore')

# %%
def load_original_data():
    return pd.read_csv("Data_Marketing_Customer_Analysis_Round2.csv" )

# %%
ca_df=load_original_data()

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
#  12  Marital Status                 10910 non-null  object
#  13  Monthly Premium Auto           10910 non-null  int64
#  14  Months Since Last Claim        10277 non-null  float64
#  15  Months Since Policy Inception  10910 non-null  int64
#  16  Number of Open Complaints      10277 non-null  float64
#  17  Number of Policies             10910 non-null  int64
#  18  Policy Type                    10910 non-null  object
#  19  Policy                         10910 non-null  object
#  20  Renew Offer Type               10910 non-null  object
#  21  Sales Channel                  10910 non-null  object
#  22  Total Claim Amount             10910 non-null  float64
#  23  Vehicle Class                  10288 non-null  object
#  24  Vehicle Size                   10288 non-null  object
#  25  Vehicle Type                   5428 non-null   object
# dtypes: float64(4), int64(5), object(17)
# memory usage: 2.2+ MB

# %%
ca_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
sns.pairplot(ca_df)

# %%
# removing outliners
## for Customer Lifetime Value
Q1 = ca_df['Customer Lifetime Value'].quantile(0.25)
Q3 = ca_df['Customer Lifetime Value'].quantile(0.75)
IQR = Q3 - Q1

# %%
clv_filter = (ca_df['Customer Lifetime Value'] >= Q1 - 1.5 * IQR) & (ca_df['Customer Lifetime Value'] <= Q3 + 1.5 * IQR)
ca_df = ca_df.loc[clv_filter]

# %%
# removing outliners
## for Monthly Premium Auto
Q1 = ca_df['Monthly Premium Auto'].quantile(0.25)
Q3 = ca_df['Monthly Premium Auto'].quantile(0.75)
IQR = Q3 - Q1

# %%
mpa_filter = (ca_df['Monthly Premium Auto'] >= Q1 - 1.5 * IQR) & (ca_df['Monthly Premium Auto'] <= Q3 + 1.5 * IQR)
ca_df = ca_df.loc[mpa_filter]

# %%
ca_df.hist(figsize = (12,12))
# Out:
# array([[<AxesSubplot:title={'center':'Customer Lifetime Value'}>,
#         <AxesSubplot:title={'center':'Income'}>,
#         <AxesSubplot:title={'center':'Monthly Premium Auto'}>],
#        [<AxesSubplot:title={'center':'Months Since Last Claim'}>,
#         <AxesSubplot:title={'center':'Months Since Policy Inception'}>,
#         <AxesSubplot:title={'center':'Number of Open Complaints'}>],
#        [<AxesSubplot:title={'center':'Number of Policies'}>,
#         <AxesSubplot:title={'center':'Total Claim Amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
ca_df.corr()
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.050343
# Income                                        0.050343  1.000000
# Monthly Premium Auto                          0.425607 -0.022527
# Months Since Last Claim                      -0.018780 -0.025869
# Months Since Policy Inception                -0.011709 -0.002037
# Number of Open Complaints                    -0.030059  0.001075
# Number of Policies                            0.228867 -0.005988
# Total Claim Amount                            0.167182 -0.407654
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.425607                -0.018780
# Income                                    -0.022527                -0.025869
# Monthly Premium Auto                       1.000000                -0.007815
# Months Since Last Claim                   -0.007815                 1.000000
# Months Since Policy Inception              0.000299                -0.044763
# Number of Open Complaints                 -0.020374                 0.008458
# Number of Policies                        -0.011221                 0.004713
# Total Claim Amount                         0.482923                -0.007300
#
#                                Months Since Policy Inception  \
# Customer Lifetime Value                            -0.011709
# Income                                             -0.002037
# Monthly Premium Auto                                0.000299
# Months Since Last Claim                            -0.044763
# Months Since Policy Inception                       1.000000
# Number of Open Complaints                           0.009690
# Number of Policies                                 -0.010966
# Total Claim Amount                                 -0.016639
#
#                                Number of Open Complaints  Number of Policies  \
# Customer Lifetime Value                        -0.030059            0.228867
# Income                                          0.001075           -0.005988
# Monthly Premium Auto                           -0.020374           -0.011221
# Months Since Last Claim                         0.008458            0.004713
# Months Since Policy Inception                   0.009690           -0.010966
# Number of Open Complaints                       1.000000            0.004466
# Number of Policies                              0.004466            1.000000
# Total Claim Amount                             -0.010556           -0.006997
#
#                                Total Claim Amount
# Customer Lifetime Value                  0.167182
# Income                                  -0.407654
# Monthly Premium Auto                     0.482923
# Months Since Last Claim                 -0.007300
# Months Since Policy Inception           -0.016639
# Number of Open Complaints               -0.010556
# Number of Policies                      -0.006997
# Total Claim Amount                       1.000000

# %%
# creating X-y split
X = ca_df.drop('Total Claim Amount', axis = 1)
y = ca_df['Total Claim Amount']

# %%
# normalizing numericals
## for Customer Lifetime Value
pt = PowerTransformer()
Customer_Lifetime_Value_Transformed = pt.fit_transform(ca_df['Customer Lifetime Value'].to_numpy().reshape(-1,1))
sns.displot(Customer_Lifetime_Value_Transformed)

# %%
# normalizing numericals
## for Monthly Premium Auto
Monthly_Premium_Auto_Transformed = pt.fit_transform(ca_df['Monthly Premium Auto'].to_numpy().reshape(-1,1))
sns.displot(Monthly_Premium_Auto_Transformed)

# %%
# replacing the normalized numerical columns
ca_df['Customer Lifetime Value Transformed'] = Customer_Lifetime_Value_Transformed
ca_df['Monthly Premium Auto Transformed'] = Monthly_Premium_Auto_Transformed
ca_df.drop(columns = ['Customer Lifetime Value', 'Monthly Premium Auto'], axis = 1, inplace=True)

# %%
# identifying categorical columns
categorical_features = ca_df.select_dtypes('object')
categorical_features
# Out:
#       Customer       State Response  Coverage             Education  \
# 0      DK49336     Arizona       No     Basic               College
# 1      KX64629  California       No     Basic               College
# 2      LZ68649  Washington       No     Basic              Bachelor
# 4      QA50777      Oregon       No   Premium              Bachelor
# 5      HO81102         NaN      NaN     Basic  High School or Below
# ...        ...         ...      ...       ...                   ...
# 10902  PP30874  California       No  Extended  High School or Below
# 10903  SU71163     Arizona       No     Basic               College
# 10906  KX53892      Oregon       No     Basic               College
# 10908  WA60547  California       No   Premium               College
# 10909  IV32877         NaN      NaN     Basic              Bachelor
#
#       Effective To Date EmploymentStatus Gender Location Code Marital Status  \
# 0               2/18/11         Employed      M      Suburban        Married
# 1               1/18/11       Unemployed      F      Suburban         Single
# 2               2/10/11         Employed      M      Suburban         Single
# 4               1/17/11    Medical Leave      F      Suburban        Married
# 5               2/14/11         Employed      M      Suburban       Divorced
# ...                 ...              ...    ...           ...            ...
# 10902           1/24/11         Employed      F      Suburban        Married
# 10903            1/7/11         Employed      M      Suburban        Married
# 10906            1/6/11         Employed      F         Urban        Married
# 10908           2/13/11         Employed      F         Urban       Divorced
# 10909            1/8/11       Unemployed      M      Suburban         Single
#
#           Policy Type        Policy Renew Offer Type Sales Channel  \
# 0      Corporate Auto  Corporate L3           Offer3         Agent
# 1       Personal Auto   Personal L3           Offer4   Call Center
# 2       Personal Auto   Personal L3           Offer3   Call Center
# 4       Personal Auto   Personal L2           Offer1        Branch
# 5       Personal Auto   Personal L3           Offer1         Agent
# ...               ...           ...              ...           ...
# 10902   Personal Auto   Personal L2           Offer2         Agent
# 10903   Personal Auto   Personal L2           Offer2        Branch
# 10906   Personal Auto   Personal L3           Offer2        Branch
# 10908   Personal Auto   Personal L1           Offer1        Branch
# 10909   Personal Auto   Personal L1           Offer4           Web
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# 5      Four-Door Car      Medsize            A
# ...              ...          ...          ...
# 10902  Four-Door Car      Medsize            A
# 10903   Two-Door Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [9564 rows x 17 columns]

# %%
ca_df['State'].value_counts()
# Out:
# California    3120
# Oregon        2540
# Arizona       1716
# Nevada         861
# Washington     778
# Name: State, dtype: int64

# %%
ca_df['Gender'].value_counts()
# Out:
# F    4876
# M    4688
# Name: Gender, dtype: int64

# %%
ca_df['Education'].value_counts(dropna=False)
# Out:
# Bachelor                2871
# College                 2844
# High School or Below    2708
# Master                   774
# Doctor                   367
# Name: Education, dtype: int64

# %%
# hot encoding for Gender
Gender_Transformed = pd.get_dummies(categorical_features['Gender'], drop_first=True)
Gender_Transformed
# Out:
#        M
# 0      1
# 1      0
# 2      1
# 4      0
# 5      1
# ...   ..
# 10902  0
# 10903  1
# 10906  0
# 10908  0
# 10909  1
#
# [9564 rows x 1 columns]

# %%
# label encoding for Education
def education_label(x):
    if x == 'High School or Below':
        return 0
    elif x == 'College':
        return 1
    elif x == 'Bachelor':
        return 2
    elif x == 'Master':
        return 3
    elif x == 'Doctor':
        return 4

# %%
ca_df['Education'] = list(map(education_label, ca_df['Education']))

# %%
ca_df
# Out:
#       Customer       State Response  Coverage  Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic          1           2/18/11
# 1      KX64629  California       No     Basic          1           1/18/11
# 2      LZ68649  Washington       No     Basic          2           2/10/11
# 4      QA50777      Oregon       No   Premium          2           1/17/11
# 5      HO81102         NaN      NaN     Basic          0           2/14/11
# ...        ...         ...      ...       ...        ...               ...
# 10902  PP30874  California       No  Extended          0           1/24/11
# 10903  SU71163     Arizona       No     Basic          1            1/7/11
# 10906  KX53892      Oregon       No     Basic          1            1/6/11
# 10908  WA60547  California       No   Premium          1           2/13/11
# 10909  IV32877         NaN      NaN     Basic          2            1/8/11
#
#       EmploymentStatus Gender  Income Location Code Marital Status  \
# 0             Employed      M   48029      Suburban        Married
# 1           Unemployed      F       0      Suburban         Single
# 2             Employed      M   22139      Suburban         Single
# 4        Medical Leave      F   23675      Suburban        Married
# 5             Employed      M   50549      Suburban       Divorced
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10908         Employed      F   64195         Urban       Divorced
# 10909       Unemployed      M       0      Suburban         Single
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 4                          NaN                             31
# 5                          2.0                             73
# ...                        ...                            ...
# 10902                     10.0                             30
# 10903                     30.0                             82
# 10906                      7.0                             68
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        Number of Open Complaints  Number of Policies     Policy Type  \
# 0                            0.0                   9  Corporate Auto
# 1                            0.0                   1   Personal Auto
# 2                            0.0                   2   Personal Auto
# 4                            NaN                   7   Personal Auto
# 5                            0.0                   7   Personal Auto
# ...                          ...                 ...             ...
# 10902                        2.0                   1   Personal Auto
# 10903                        4.0                   1   Personal Auto
# 10906                        0.0                   6   Personal Auto
# 10908                        4.0                   6   Personal Auto
# 10909                        0.0                   3   Personal Auto
#
#              Policy Renew Offer Type Sales Channel  Total Claim Amount  \
# 0      Corporate L3           Offer3         Agent          292.800000
# 1       Personal L3           Offer4   Call Center          744.924331
# 2       Personal L3           Offer3   Call Center          480.000000
# 4       Personal L2           Offer1        Branch          707.925645
# 5       Personal L3           Offer1         Agent          292.800000
# ...             ...              ...           ...                 ...
# 10902   Personal L2           Offer2         Agent          655.200000
# 10903   Personal L2           Offer2        Branch          355.200000
# 10906   Personal L3           Offer2        Branch          273.018929
# 10908   Personal L1           Offer1        Branch          618.288849
# 10909   Personal L1           Offer4           Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type  \
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# 5      Four-Door Car      Medsize            A
# ...              ...          ...          ...
# 10902  Four-Door Car      Medsize            A
# 10903   Two-Door Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
#        Customer Lifetime Value Transformed  Monthly Premium Auto Transformed
# 0                                -0.219817                         -1.516223
# 1                                -1.773421                         -1.221720
# 2                                 1.992150                          0.810670
# 4                                 1.019369                          1.293439
# 5                                -0.246518                         -1.516223
# ...                                    ...                               ...
# 10902                            -0.811381                          0.470997
# 10903                            -1.328443                         -0.431820
# 10906                            -0.041891                         -1.130336
# 10908                             1.566363                          1.987336
# 10909                             0.482194                          0.844199
#
# [9564 rows x 25 columns]
