# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Activity 1

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
def rename_column_file1(file1):
    file1.rename(columns={'Customer':'customer_id', 'ST':'state', 'GENDER':'gender', 'Education':'education', 'Customer Lifetime Value':'clv',
       'Income':'income', 'Monthly Premium Auto':'monthly_premium_auto', 'Number of Open Complaints':'number_of_open_complaints',
       'Policy Type':'policy_type', 'Vehicle Class':'vehicle_class', 'Total Claim Amount':'total_claim_amount'}, inplace=True)
    return file1

# %%
rename_column_file1(file1)
# Out:
#      customer_id       state gender             education          clv  \
# 0        RB50392  Washington    NaN                Master          NaN
# 1        QZ44356     Arizona      F              Bachelor   697953.59%
# 2        AI49188      Nevada      F              Bachelor  1288743.17%
# 3        WW63253  California      M              Bachelor   764586.18%
# 4        GA49547  Washington      M  High School or Below   536307.65%
# ...          ...         ...    ...                   ...          ...
# 4003         NaN         NaN    NaN                   NaN          NaN
# 4004         NaN         NaN    NaN                   NaN          NaN
# 4005         NaN         NaN    NaN                   NaN          NaN
# 4006         NaN         NaN    NaN                   NaN          NaN
# 4007         NaN         NaN    NaN                   NaN          NaN
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
rename_column_file1(file2)
# Out:
#     customer_id       state gender education          clv  income  \
# 0       GS98873     Arizona      F  Bachelor   323912.47%   16061
# 1       CW49887  California      F    Master   462680.11%   79487
# 2       MY31220  California      F   College   899704.02%   54230
# 3       UH35128      Oregon      F   College  2580706.30%   71210
# 4       WH52799     Arizona      F   College   380812.21%   94903
# ..          ...         ...    ...       ...          ...     ...
# 991     HV85198     Arizona      M    Master   847141.75%   63513
# 992     BS91566     Arizona      F   College   543121.91%   58161
# 993     IL40123      Nevada      F   College   568964.41%   83640
# 994     MY32149  California      F    Master   368672.38%       0
# 995     SA91515  California      M  Bachelor   399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                      88                    1/0/00          633.600000
# ...

# %%
def rename_column_file3(file3):
    file3.rename(columns={'Customer':'customer_id', 'State':'state', 'Gender':'gender', 'Education':'education', 'Customer Lifetime Value':'clv',
       'Income':'income', 'Monthly Premium Auto':'monthly_premium_auto', 'Number of Open Complaints':'number_of_open_complaints',
       'Policy Type':'policy_type', 'Vehicle Class':'vehicle_class', 'Total Claim Amount':'total_claim_amount'}, inplace=True)
    return file3

# %%
rename_column_file3(file3)
# Out:
#      customer_id       state           clv             education gender  \
# 0        SA25987  Washington   3479.137523  High School or Below      M
# 1        TB86706     Arizona   2502.637401                Master      M
# 2        ZL73902      Nevada   3265.156348              Bachelor      F
# 3        KX23516  California   4455.843406  High School or Below      F
# 4        FN77294  California   7704.958480  High School or Below      M
# ...          ...         ...           ...                   ...    ...
# 7065     LA72316  California  23405.987980              Bachelor      M
# 7066     PK87824  California   3096.511217               College      F
# 7067     TD14365  California   8163.890428              Bachelor      M
# 7068     UP19263  California   7524.442436               College      M
# 7069     Y167826  California   2611.836866               College      M
#
#       income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
ca_df = pd.concat([file1,file2,file3], axis=0).reset_index(drop=True)
ca_df
# Out:
#       customer_id       state gender             education          clv  \
# 0         RB50392  Washington    NaN                Master          NaN
# 1         QZ44356     Arizona      F              Bachelor   697953.59%
# 2         AI49188      Nevada      F              Bachelor  1288743.17%
# 3         WW63253  California      M              Bachelor   764586.18%
# 4         GA49547  Washington      M  High School or Below   536307.65%
# ...           ...         ...    ...                   ...          ...
# 12069     LA72316  California      M              Bachelor  23405.98798
# 12070     PK87824  California      F               College  3096.511217
# 12071     TD14365  California      M              Bachelor  8163.890428
# 12072     UP19263  California      M               College  7524.442436
# 12073     Y167826  California      M               College  2611.836866
#
#         income  monthly_premium_auto number_of_open_complaints  \
# ...

# %%
# deleting the column customer
def drop_column(ca_df):
    ca_df.drop(columns=['customer_id'], inplace=True)
    return ca_df

# %%
drop_column(ca_df)
# Out:
#             state gender             education          clv   income  \
# 0      Washington    NaN                Master          NaN      0.0
# 1         Arizona      F              Bachelor   697953.59%      0.0
# 2          Nevada      F              Bachelor  1288743.17%  48767.0
# 3      California      M              Bachelor   764586.18%      0.0
# 4      Washington      M  High School or Below   536307.65%  36357.0
# ...           ...    ...                   ...          ...      ...
# 12069  California      M              Bachelor  23405.98798  71941.0
# 12070  California      F               College  3096.511217  21604.0
# 12071  California      M              Bachelor  8163.890428      0.0
# 12072  California      M               College  7524.442436  21941.0
# 12073  California      M               College  2611.836866      0.0
#
#        monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   clv                        9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly_premium_auto       9137 non-null   float64
#  6   number_of_open_complaints  9137 non-null   object
#  7   policy_type                9137 non-null   object
#  8   vehicle_class              9137 non-null   object
#  9   total_claim_amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 943.4+ KB

# %%
# correcting data types (1)
## ca_df['clv'] = list(map(lambda x: x.str.rstrip('%').astype('float')/100 if (str(x)[-1] == '%') else (x), ca_df['clv']))
ca_df['clv'] = list(map(lambda x: x if (type(x) == float) else float(x[0:-1])/100, ca_df['clv']))

# %%
# correcting data types (2)
ca_df['number_of_open_complaints'].value_counts(dropna=False)
# Out:
# 0         5629
# NaN       2937
# 1/0/00    1626
# 1          765
# 2          283
# 1/1/00     247
# 3          230
# 4          119
# 1/2/00      93
# 1/3/00      60
# 5           44
# 1/4/00      29
# 1/5/00      12
# Name: number_of_open_complaints, dtype: int64

# %%
ca_df['number_of_open_complaints'] = list(map(lambda x:x if (type(x) != str) else int(x[2]), ca_df['number_of_open_complaints']))

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   clv                        9130 non-null   float64
#  4   income                     9137 non-null   float64
#  5   monthly_premium_auto       9137 non-null   float64
#  6   number_of_open_complaints  9137 non-null   float64
#  7   policy_type                9137 non-null   object
#  8   vehicle_class              9137 non-null   object
#  9   total_claim_amount         9137 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 943.4+ KB

# %%
# standardizing data (1)
ca_df.gender.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'Male'
    elif x in ('F', 'female', 'Femal'):
        return 'Female'
    else:
        return x

# %%
ca_df['gender'] = list(map(clean_gender, ca_df['gender']))

# %%
ca_df.gender.unique()
# Out:
# array([nan, 'Female', 'Male'], dtype=object)

# %%
# standardizing data (2)
ca_df['state'].value_counts(dropna=False)
# Out:
# California    3032
# NaN           2937
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: state, dtype: int64

# %%
def clean_state(x):
    if x == 'AZ':
        return 'Arizona'
    elif x == 'Cali':
        return 'California'
    elif x == 'WA':
        return 'Washington'
    else:
        return x

# %%
ca_df['state'] = list(map(clean_state, ca_df['state']))

# %%
ca_df['state'].value_counts(dropna=False)
# Out:
# California    3152
# NaN           2937
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: state, dtype: int64

# %%
# removing duplicates
ca_df.drop_duplicates(inplace=True)

# %%
ca_df.reset_index(drop=True)
# Out:
#            state  gender             education           clv   income  \
# 0     Washington     NaN                Master           NaN      0.0
# 1        Arizona  Female              Bachelor   6979.535900      0.0
# 2         Nevada  Female              Bachelor  12887.431700  48767.0
# 3     California    Male              Bachelor   7645.861800      0.0
# 4     Washington    Male  High School or Below   5363.076500  36357.0
# ...          ...     ...                   ...           ...      ...
# 8868  California    Male              Bachelor  23405.987980  71941.0
# 8869  California  Female               College   3096.511217  21604.0
# 8870  California    Male              Bachelor   8163.890428      0.0
# 8871  California    Male               College   7524.442436  21941.0
# 8872  California    Male               College   2611.836866      0.0
#
#       monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
ca_df.describe().T
# Out:
#                             count          mean           std          min  \
# clv                        8865.0   7980.711365   6825.678703  1898.007675
# income                     8872.0  37817.001803  30433.134529     0.000000
# monthly_premium_auto       8872.0    110.181357    586.092759    61.000000
# number_of_open_complaints  8872.0      0.385032      0.908553     0.000000
# total_claim_amount         8872.0    430.020378    290.862077     0.099007
#
#                                    25%           50%           75%  \
# clv                        3979.388200   5775.517825   8927.134298
# income                        0.000000  34312.000000  62449.000000
# monthly_premium_auto         68.000000     83.000000    109.000000
# number_of_open_complaints     0.000000      0.000000      0.000000
# total_claim_amount          263.767313    374.882131    545.468252
#
#                                     max
# clv                        83325.381190
# ...

# %%
# replacing missing values with the mean of the column (DO MEAN FOR NON-ZEROES FROM INCOME!!!!!!!!!!)
ca_df['clv'].fillna(value=ca_df['clv'].mean(axis=0), inplace=True)
ca_df['income'].fillna(value=ca_df['income'].mean(axis=0), inplace=True)
ca_df['monthly_premium_auto'].fillna(value=ca_df['monthly_premium_auto'].mean(axis=0), inplace=True)
ca_df['number_of_open_complaints'].fillna(value=round(ca_df['number_of_open_complaints'].mean(axis=0),0), inplace=True)
ca_df['total_claim_amount'].fillna(value=ca_df['total_claim_amount'].mean(axis=0), inplace=True)

# %%
ca_df.describe().T
# Out:
#                             count          mean           std          min  \
# clv                        8873.0   7980.711365   6822.600607  1898.007675
# income                     8873.0  37817.001803  30431.419358     0.000000
# monthly_premium_auto       8873.0    110.181357    586.059727    61.000000
# number_of_open_complaints  8873.0      0.384988      0.908511     0.000000
# total_claim_amount         8873.0    430.020378    290.845685     0.099007
#
#                                    25%           50%           75%  \
# clv                        3979.718986   5780.182197   8923.154803
# income                        0.000000  34317.000000  62448.000000
# monthly_premium_auto         68.000000     83.000000    109.000000
# number_of_open_complaints     0.000000      0.000000      0.000000
# total_claim_amount          263.825690    374.899600    545.291103
#
#                                     max
# clv                        83325.381190
# ...

# %%
ca_df
# Out:
#             state  gender             education           clv   income  \
# 0      Washington     NaN                Master   7980.711365      0.0
# 1         Arizona  Female              Bachelor   6979.535900      0.0
# 2          Nevada  Female              Bachelor  12887.431700  48767.0
# 3      California    Male              Bachelor   7645.861800      0.0
# 4      Washington    Male  High School or Below   5363.076500  36357.0
# ...           ...     ...                   ...           ...      ...
# 12069  California    Male              Bachelor  23405.987980  71941.0
# 12070  California  Female               College   3096.511217  21604.0
# 12071  California    Male              Bachelor   8163.890428      0.0
# 12072  California    Male               College   7524.442436  21941.0
# 12073  California    Male               College   2611.836866      0.0
#
#        monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %% [markdown]
# # Activity 2

# %%
# recategorizing state to zone
def rename_region(x):
    if x == 'California':
        return 'West'
    elif x == 'Washington':
        return 'East'
    elif x == 'Oregon':
        return 'North West'
    elif x == 'Arizona' or 'Nevada':
        return 'Central'
    else:
        return x

# %%
ca_df['state'] = list(map(rename_region, ca_df['state']))

# %%
ca_df = ca_df.rename(columns={'state':'zone'})

# %%
ca_df['zone'].value_counts()
# Out:
# West          3038
# Central       2533
# North West    2510
# East           792
# Name: zone, dtype: int64

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8873 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   zone                       8873 non-null   object
#  1   gender                     8750 non-null   object
#  2   education                  8872 non-null   object
#  3   clv                        8873 non-null   float64
#  4   income                     8873 non-null   float64
#  5   monthly_premium_auto       8873 non-null   float64
#  6   number_of_open_complaints  8873 non-null   float64
#  7   policy_type                8872 non-null   object
#  8   vehicle_class              8872 non-null   object
#  9   total_claim_amount         8873 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 762.5+ KB

# %%
# changing all strings to lower case
ca_df = ca_df.applymap(lambda x:x.lower() if type(x) == str else x)

# %%
ca_df.head()
# Out:
#       zone  gender             education           clv   income  \
# 0     east     NaN                master   7980.711365      0.0
# 1  central  female              bachelor   6979.535900      0.0
# 2  central  female              bachelor  12887.431700  48767.0
# 3     west    male              bachelor   7645.861800      0.0
# 4     east    male  high school or below   5363.076500  36357.0
#
#    monthly_premium_auto  number_of_open_complaints     policy_type  \
# 0                1000.0                        0.0   personal auto
# 1                  94.0                        0.0   personal auto
# 2                 108.0                        0.0   personal auto
# 3                 106.0                        0.0  corporate auto
# 4                  68.0                        0.0   personal auto
#
#    vehicle_class  total_claim_amount
# 0  four-door car            2.704934
# 1  four-door car         1131.464935
# 2   two-door car          566.472247
# ...
